# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C://Datasets//propData.csv")
print(df.shape)
print(df.dtypes)
df.head(9)
# Out:
# (9, 7)
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS     object
# NUM_BATH         object
# SQ_FT            object
# dtype: object
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df.shape
# Out:
# (9, 7)

# %%
#df['NUM_BATH'] = pd.to_numeric(df['NUM_BATH'],errors='coerce')   or below method
df['NUM_BATH']=df['NUM_BATH'].replace('^[^0-9]+$', np.NaN, regex=True)
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2      NaN   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df['OWN_OCCUPIED'] = df['OWN_OCCUPIED'].replace('\d+', np.NaN, regex = True)
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Fujitsu\AppData\Local\Temp\ipykernel_16472\2393917757.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['OWN_OCCUPIED'] = df['OWN_OCCUPIED'].replace('\d+', np.NaN, regex = True)
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY          NaN            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2      NaN   950
# ...

# %%
df2 = df.isnull().sum()
print(df2);
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    2
# NUM_BATH        2
# SQ_FT           1
# dtype: int64

# %%
df['NUM_BATH'] = pd.to_numeric(df['NUM_BATH'],errors='coerce')
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS  NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3       1.0  1000
# 1  100002000.0   197.0   LEXINGTON            N            3       1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN       1.0   850
# 3  100004000.0   201.0    BERKELEY           12            1       NaN   700
# 4          NaN   203.0    BERKELEY            Y            3       2.0  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN       1.0   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2       NaN   950
# 7  100008000.0   213.0     TREMONT            Y            1       1.0   NaN
# 8  100009000.0   215.0     TREMONT            Y           na       2.0  1800

# %%
#NUM BATH to Numeric

# %%
df['SQ_FT'] = pd.to_numeric(df['SQ_FT'],errors='coerce')
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS  NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3       1.0  1000.0
# 1  100002000.0   197.0   LEXINGTON            N            3       1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N          NaN       1.0   850.0
# 3  100004000.0   201.0    BERKELEY           12            1       NaN   700.0
# 4          NaN   203.0    BERKELEY            Y            3       2.0  1600.0
# 5  100006000.0   207.0    BERKELEY            Y          NaN       1.0   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN            2       NaN   950.0
# 7  100008000.0   213.0     TREMONT            Y            1       1.0     NaN
# 8  100009000.0   215.0     TREMONT            Y           na       2.0  1800.0

# %%
df['NUM_BEDROOMS'] = pd.to_numeric(df['NUM_BEDROOMS'],errors='coerce')
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           NaN       1.0
# 3  100004000.0   201.0    BERKELEY           12           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           1.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           NaN       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = df2.index
y = df2.values

# %%
plt.figure(figsize = (10,3))
barplt=sns.barplot(x=x, y=y)
plt.title('Miissing values summary')
plt.ylabel('number of missing values')
plt.xlabel('Column name')
# Out:
# Text(0.5, 0, 'Column name')

# %%
df.head(9)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0   104.0      PUTNAM            Y           3.0       1.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0       1.5
# 2  100003000.0     NaN   LEXINGTON            N           NaN       1.0
# 3  100004000.0   201.0    BERKELEY           12           1.0       NaN
# 4          NaN   203.0    BERKELEY            Y           3.0       2.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN       1.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0       NaN
# 7  100008000.0   213.0     TREMONT            Y           1.0       1.0
# 8  100009000.0   215.0     TREMONT            Y           NaN       2.0
#
#     SQ_FT
# 0  1000.0
# 1     NaN
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7     NaN
# 8  1800.0

# %%
df.shape
# Out:
# (9, 7)

# %%
print(df.dtypes)
# Out:
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS    float64
# NUM_BATH        float64
# SQ_FT           float64
# dtype: object

# %%
df.to_csv("C://Datasets//propData_c.csv",index=False)
